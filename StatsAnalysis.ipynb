# %%
import pandas as pd

# %%
df = pd.read_csv('./BoxingHeartRateStats.csv')

# %%
df
# Out:
#      Coach  Max HR  Average HR     Class
# 0    Chris     173         151    Fitbox
# 1     Trey     175         156  Personal
# 2     Jojo     176         144    Fitbox
# 3    Maura     174         150  Personal
# 4   Keller     178         145    Fitbox
# 5    Logan     170         141  Skillbox
# 6     Josh     180         157    Fitbox
# 7     Trey     170         146   Contact
# 8     Josh     172         155    Fitbox
# 9     Jojo     172         152    Fitbox
# 10   Chris     178         160    Fitbox
# 11    Trey     179         155  Personal
# 12   Maura     180         151    Fitbox
# 13   Logan     177         164   Corebox
# 14  Keller     178         153    Fitbox
# 15   Logan     171         145   Contact
# 16   Chris     170         147    Fitbox
# 17    Trey     173         149   Contact
# 18   Logan     177         146    Fitbox
# 19    Dean     175         151   Contact
# 20   Maura     177         156    Fitbox
# 21   Chris     171         154    Fitbox
# ...

# %%
df['Coach'].value_counts()
# Out:
# Josh      10
# Chris      9
# Maura      8
# Trey       8
# Logan      6
# Dean       3
# Jojo       2
# Keller     2
# Name: Coach, dtype: int64

# %%
df['Class'].value_counts()
# Out:
# Fitbox      33
# Contact      9
# Personal     4
# Corebox      1
# Skillbox     1
# Name: Class, dtype: int64

# %%
df.groupby('Coach')['Max HR'].max().sort_values(ascending=False)
# Out:
# Coach
# Maura     180
# Josh      180
# Chris     180
# Trey      179
# Keller    178
# Logan     177
# Dean      177
# Jojo      176
# Name: Max HR, dtype: int64

# %%
df.groupby('Coach')['Average HR'].max().sort_values(ascending=False)
# Out:
# Coach
# Logan     164
# Josh      161
# Chris     160
# Maura     159
# Trey      156
# Dean      154
# Keller    153
# Jojo      152
# Name: Average HR, dtype: int64

# %%
df.groupby('Class')['Max HR'].max().sort_values(ascending=False)
# Out:
# Class
# Fitbox      180
# Personal    179
# Contact     179
# Corebox     177
# Skillbox    170
# Name: Max HR, dtype: int64

# %%
df.groupby('Class')['Average HR'].max().sort_values(ascending=False)
# Out:
# Class
# Corebox     164
# Fitbox      161
# Personal    156
# Contact     154
# Skillbox    141
# Name: Average HR, dtype: int64
